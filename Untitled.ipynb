# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import cv2
import numpy as np

img = cv2.imread('ML/0/0_1.jpg',0)

# %%
plt.imshow(img, cmap='gray')

# %%
np.max(img)
# Out:
# 207

# %%
np.min(img)
# Out:
# 47

# %%
47 + 207 / 2
# Out:
# 150.5

# %%
img2 = img > 150.2

# %%
ret, thresh1 = cv2.threshold(img,90,255,cv2.THRESH_BINARY)

# %%
plt.imshow(thresh1, cmap='gray')

# %%
img = thresh1

# %%
idx = 0
for i, row in enumerate(img):
    if 0 in row:
        idx = i
        break

# %%
idx
# Out:
# 57

# %%
plt.imshow(img, cmap='gray')
plt.axhline(y=57)
